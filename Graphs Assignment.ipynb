# %% [markdown]
# # Python Graded Assignment

# %% [markdown]
# **Group Member 1:** Anugya Shaw (D19006)
# <br>
# **Group Member 2:** Aiswarya Alapuzha (D19002)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Graph is a custom function which is created to plot **univariate analysis** from a given dataset on the **basis** of the **data type** of the variables(categorical and numerical).It contains 3 arguments [df(mandatory) to call the dataframe, l (optional, default = all columns) list of columns to plot, directory(optional,default = current directory) file path where plots are to be saved].
# <br>
# It aims to plot **histogram and boxplot** for *numerical* variables and **barplot** for *categorical* variables.It also **saves** the plots in the default or given directory.

# %%
#function for plotting graphs of default all columns
def graph1 (df):  
    
    import numpy as np   #importing the necessary libraries
    import pandas as pd
    import matplotlib.pyplot as plt
    import os

    sns.set()
    for i in df:
        if (np.dtype(df[i])!='object' and len(np.unique(df[i]))>15): #checking for categorical variables
        #plotting histograms
            df.hist(column=i,grid= False, figsize=(6,4))
            plt.xlabel(i,fontsize=15)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Histogram of '+i.upper(),fontsize=15)
            plt.savefig(directory+"/Histogram of "+i+".png")
            plt.show()
           
         # plotting box plots
            df.boxplot(column=i)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Boxplot of '+i.upper(),fontsize=15)
            plt.savefig(directory+"/Boxplot of "+i+".png")
            plt.show()
        else:
          #plotting bar plots  
            df[i].value_counts().plot(kind='barh',color='green',fontsize=15)
            plt.xlabel('Number of Elements',fontsize=15)
            plt.ylabel(i,fontsize=15)
            plt.title('Bargraph of '+i,fontsize=15)
            plt.savefig(directory+"/Bargraph of "+i+".png")
            plt.show()

# %%
#actual function to plot graphs for Cars dataset
def graphs(df,l=None,directory=None):
    import numpy as np   #importing the necessary libraries
    import pandas as pd
    import matplotlib.pyplot as plt
    import os

    sns.set() 

           
    if directory is None:
           
        directory=os.getcwd() #current working directory is stored
        
           
    if l:
        count=1
        d={}  
        name=[] #creating a list with inputed column names
        for i in df:
            d[count]=i
            count+=1
        for i in l:
            name.append(d[i])
        #separating the categorical and numerical data
        categorical=[]
        numerical=[]
        
        
        for i in name:
            if (np.dtype(df[i])=='object'or len(np.unique(df[i]))<15):
                categorical.append(i)
            else :
                numerical.append(i)
        print('Categorical columns are',categorical)
        print('Numerical columns are',numerical)
        
        for i in categorical:
            df[i].value_counts().plot(kind='barh',color='green',fontsize=15)
            plt.xlabel('Number of Elements',fontsize=15)
            plt.ylabel(i,fontsize=15)
            plt.title('Bargraph of '+i,fontsize=15)
            plt.savefig(directory+"/Bargraph of "+i+".png")
            plt.show()
        
        for i in numerical:
            #plotting histogram
            df.hist(column=i,grid= False, figsize=(6,4))
            plt.xlabel(i,fontsize=15)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Histogram of '+i.upper(),fontsize=15)
            plt.savefig(directory+"/Histogram of "+i+".png")
            plt.show()
            
           #plotting boxplot
            df.boxplot(column=i,fontsize=15)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Boxplot of '+i.upper(),fontsize=15)
            plt.savefig(directory+"\\Boxplot of "+i+".png")
            plt.show()
            
    elif(l==[]):
        print('Enter the columns you want to plot the graph: ')
    elif (l==None):
        return (graph1(df))

# %%
#reading the csv file
cars=pd.read_csv('C:\\Users\\Anugya\\Desktop\\Term 1\\ML1\\cars.csv')
cars.head()
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0         130
# 1          Buick Skylark 320  15.0          8         350.0         165
# 2         Plymouth Satellite  18.0          8         318.0         150
# 3              AMC Rebel SST  16.0          8         304.0         150
# 4                Ford Torino  17.0          8         302.0         140
#
#    Weight  Acceleration  Model Origin
# 0    3504          12.0     70     US
# 1    3693          11.5     70     US
# 2    3436          11.0     70     US
# 3    3433          12.0     70     US
# 4    3449          10.5     70     US

# %%
#execution of the function graphs
graphs(cars,[2,3,4,5,7])
# Out:
# Categorical columns are ['Cylinders']
# Numerical columns are ['MPG', 'Displacement', 'Horsepower', 'Acceleration']

# %% [markdown]
# ## First Improvisation

# %% [markdown]
# Creating a windows GUI to import csv file as per the choice of user, using Tkinter.

# %%
import tkinter as tk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tkinter import filedialog

root= tk.Tk()

canvas1 = tk.Canvas(root, width = 300, height = 300, bg = 'lightsteelblue2', relief = 'raised')
canvas1.pack()

def getCSV ():
    global df
    
    import_file_path = filedialog.askopenfilename()
    df = pd.read_csv (import_file_path)
    print (df)
    
browseButton_CSV = tk.Button(text="      Import CSV File     ", command=getCSV, bg='green', fg='white', font=('helvetica', 12, 'bold'))
canvas1.create_window(150, 150, window=browseButton_CSV)

root.mainloop()
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      41          1      Travel_Rarely                   Sales
# 1      49          0  Travel_Frequently  Research & Development
# 2      37          1      Travel_Rarely  Research & Development
# 3      33          0  Travel_Frequently  Research & Development
# 4      27          0      Travel_Rarely  Research & Development
# 5      32          0  Travel_Frequently  Research & Development
# 6      59          0      Travel_Rarely  Research & Development
# 7      30          0      Travel_Rarely  Research & Development
# 8      38          0  Travel_Frequently  Research & Development
# 9      36          0      Travel_Rarely  Research & Development
# 10     35          0      Travel_Rarely  Research & Development
# 11     29          0      Travel_Rarely  Research & Development
# 12     31          0      Travel_Rarely  Research & Development
# 13     34          0      Travel_Rarely  Research & Development
# 14     28          1      Travel_Rarely  Research & Development
# 15     29          0      Travel_Rarely  Research & Development
# 16     32          0      Travel_Rarely  Research & Development
# 17     22          0         Non-Travel  Research & Development
# 18     53          0      Travel_Rarely                   Sales
# 19     38          0      Travel_Rarely  Research & Development
# 20     24          0         Non-Travel  Research & Development
# 21     36          1      Travel_Rarely                   Sales
# 22     34          0      Travel_Rarely  Research & Development
# 23     21          0      Travel_Rarely  Research & Development
# 24     34          1      Travel_Rarely  Research & Development
# 25     53          0      Travel_Rarely  Research & Development
# 26     32          1  Travel_Frequently  Research & Development
# 27     42          0      Travel_Rarely                   Sales
# 28     44          0      Travel_Rarely  Research & Development
# 29     46          0      Travel_Rarely                   Sales
# ...   ...        ...                ...                     ...
# 1440   36          0  Travel_Frequently  Research & Development
# 1441   56          0         Non-Travel  Research & Development
# 1442   29          1      Travel_Rarely  Research & Development
# 1443   42          0      Travel_Rarely  Research & Development
# 1444   56          1      Travel_Rarely  Research & Development
# 1445   41          0      Travel_Rarely  Research & Development
# 1446   34          0      Travel_Rarely                   Sales
# 1447   36          0         Non-Travel                   Sales
# 1448   41          0      Travel_Rarely                   Sales
# 1449   32          0      Travel_Rarely  Research & Development
# 1450   35          0      Travel_Rarely         Human Resources
# 1451   38          0      Travel_Rarely                   Sales
# 27                   10                3               9                   7
# 28                   24                3              22                   6
# 29                   22                2               2                   2
# ...                 ...              ...             ...                 ...
# 1440                 18                3               4                   2
# 1441                 13                2              13                  12
# 1442                  4                4               2                   2
# 1443                 24                2              22                   6
# 1444                 14                1              10                   9
# 1445                 21                3              20                   7
# 1446                  8                3               8                   7
# 1447                 15                2              15                  12
# 1448                 14                3               5                   4
# 1449                  4                3               4                   2
# 1450                  9                3               9                   0
# 1451                 10                3              10                   7
# 1452                 12                3               6                   3
# 1453                  8                2               6                   3
# 1454                  8                3               5                   3
# 1455                  8                3               2                   2
# 1456                 10                4              10                   2
# 1457                 20                3               5                   3
# 1458                  4                3               4                   3
# 1459                 10                3               4                   3
# 1460                  5                1               5                   4
# 1461                 20                3               3                   2
# 1462                 21                2              20                   9
# 1463                 10                3               9                   4
# 1464                  5                3               4                   2
# 1465                 17                3               5                   2
# 1466                  9                3               7                   7
# 1467                  6                3               6                   2
# 1468                 17                2               9                   6
# 1469                  6                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# 5                           3                     6
# 6                           0                     0
# 7                           0                     0
# 8                           1                     8
# 9                           7                     7
# 10                          0                     3
# 11                          0                     8
# 12                          4                     3
# 13                          1                     2
# 14                          0                     3
# 15                          8                     8
# 16                          0                     5
# 17                          0                     0
# 18                          3                     7
# 19                          1                     2
# 20                          1                     3
# 21                          0                     3
# 22                          2                    11
# 23                          0                     0
# 24                          1                     3
# 25                          4                     8
# 26                          6                     7
# 27                          4                     2
# 28                          5                    17
# 29                          2                     1
# ...                       ...                   ...
# 1440                        0                     2
# 1441                        1                     9
# 1442                        2                     2
# 1443                        4                    14
# 1444                        9                     8
# 1445                        0                    10
# 1446                        1                     7
# 1447                       11                    11
# 1448                        0                     4
# 1449                        1                     2
# 1450                        1                     7
# 1451                        1                     9
# 1452                        0                     1
# 1453                        0                     0
# 1454                        0                     1
# 1455                        2                     2
# 1456                        0                     2
# 1457                        0                     2
# 1458                        1                     1
# 1459                        0                     3
# 1460                        0                     4
# 1461                        2                     0
# 1462                        9                     6
# 1463                        1                     7
# 1464                        0                     0
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 19 columns]

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
#   MaritalStatus  MonthlyIncome OverTime  TotalWorkingYears  WorkLifeBalance  \
# 0        Single           5993      Yes                  8                1
# 1       Married           5130       No                 10                3
# 2        Single           2090      Yes                  7                3
# 3       Married           2909      Yes                  8                3
# 4       Married           3468       No                  6                3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager
# 0                     5
# 1                     7
# 2                     0
# 3                     0
# 4                     2

# %%
#function for plotting graphs of default all columns
def graph1 (df):  
    
    import numpy as np   #importing the necessary libraries
    import pandas as pd
    import matplotlib.pyplot as plt
    import os

    sns.set()
    for i in df:
        if (np.dtype(df[i])!='object' and len(np.unique(df[i]))>15): #checking for categorical variables
        #plotting histograms
            df.hist(column=i,grid= False, figsize=(6,4))
            plt.xlabel(i,fontsize=15)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Histogram of '+i.upper(),fontsize=15)
            plt.savefig(directory+"/Histogram of "+i+".png")
            plt.show()
           
         # plotting box plots
            df.boxplot(column=i)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Boxplot of '+i.upper(),fontsize=15)
            plt.savefig(directory+"/Boxplot of "+i+".png")
            plt.show()
        else:
          #plotting bar plots  
            df[i].value_counts().plot(kind='barh',color='green',fontsize=15)
            plt.xlabel('Number of Elements',fontsize=15)
            plt.ylabel(i,fontsize=15)
            plt.title('Bargraph of '+i,fontsize=15)
            plt.savefig(directory+"/Bargraph of "+i+".png")
            plt.show()

# %%
#actual function to plot graphs for Attrition dataset
def graphs(df,l=None,directory=None):
    import numpy as np   #importing the necessary libraries
    import pandas as pd
    import matplotlib.pyplot as plt
    import os

    sns.set() 

           
    if directory is None:
           
        directory=os.getcwd() #current working directory is stored
        
           
    if l:
        count=1
        d={}  
        name=[] #creating a list with inputed column names
        for i in df:
            d[count]=i
            count+=1
        for i in l:
            name.append(d[i])
        #separating the categorical and numerical data
        categorical=[]
        numerical=[]
        
        
        for i in name:
            if (np.dtype(df[i])=='object'or len(np.unique(df[i]))<15):
                categorical.append(i)
            else :
                numerical.append(i)
        print('Categorical columns are',categorical)
        print('Numerical columns are',numerical)
        
        for i in categorical:
            df[i].value_counts().plot(kind='barh',color='green',fontsize=15)
            plt.xlabel('Number of Elements',fontsize=15)
            plt.ylabel(i,fontsize=15)
            plt.title('Bargraph of '+i,fontsize=15)
            plt.savefig(directory+"/Bargraph of "+i+".png")
            plt.show()
        
        for i in numerical:
            #plotting histogram
            df.hist(column=i,grid= False, figsize=(6,4))
            plt.xlabel(i,fontsize=15)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Histogram of '+i.upper(),fontsize=15)
            plt.savefig(directory+"/Histogram of "+i+".png")
            plt.show()
            
           #plotting boxplot
            df.boxplot(column=i,fontsize=15)
            plt.ylabel('Number of elements',fontsize=12)
            plt.title('Boxplot of '+i.upper(),fontsize=15)
            plt.savefig(directory+"\\Boxplot of "+i+".png")
            plt.show()
            
    elif(l==[]):
        print('Enter the columns you want to plot the graph: ')
    elif (l==None):
        return (graph1(df))

# %%
graphs(df,[1,2,3,4,5])
# Out:
# Categorical columns are ['Attrition', 'BusinessTravel', 'Department', 'EducationField']
# Numerical columns are ['Age']

# %% [markdown]
# ## Second Improvisation

# %% [markdown]
# Creating a local package to hold the graph function, so we can import the function as module when required.

# %% [markdown]
# **Name of folder in which the package is stored:** assignment
# <br>
# **Name of package:** graph_pack
# <br>
# **Name of class:** graphical
# <br>
# **Name of function:** graphs(df,l,directory)

# %%
#get the current working directory
os.getcwd()
# Out:
# 'C:\\Users\\Anugya\\Downloads\\assignment'

# %%
import graph_pack as gp
#from  import graph_pack.graphical.graphs()
gp.graphical.graphs(df,[2,3,4])
